# %%
import db

# %%
import coin_repository

# %%
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
import strategies as st

# %%
import simulator

# %%
sim = simulator.Simulator(st.GcdcStrategy(coin_repository.CoinRepository('EOS')))

# %%
sim.get_data_frame()['benefit'].plot()

# %%
sim.get_mdd()
# Out:
# 0.6045656678577773

# %%
sim.get_cagr()
# Out:
# 9.190055828660281

# %%
# data.get_data_frame()['benefit'].plot()

# %%
eos_repo = coin_repository.CoinRepository('EOS')
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=0.7))
sim_a = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=-1))
sim_b = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=-1, k_factor=20))
sim_c = simulator.Simulator(st.VolatilityBreakoutStrategy(eos_repo, k_value=-1, k_factor=10))

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.251818333909252 0.254644483386662 0.2491096289593807 0.343085924957246 0.18929693298922878

# %%
pd.DataFrame({
#     '0.3': sim_3.get_data_frame()['benefit'],
    '0.5': sim_5.get_data_frame()['benefit'],
#     '0.7': sim_7.get_data_frame()['benefit'],
    '-1' : sim_a.get_data_frame()['benefit'],
    '-1 / 20' : sim_b.get_data_frame()['benefit'],
    '-1 / 10' : sim_c.get_data_frame()['benefit']
}).plot()

# %%
print(sim_3.get_cagr(), sim_5.get_cagr(), sim_7.get_cagr(), sim_a.get_cagr(), sim_b.get_cagr())
# Out:
# 68.03251521774837 26.96385745016602 11.674088016852592 13.30573977606452 27.712825201160676

# %%
print(sim_3.get_winning_rate(), sim_5.get_winning_rate(), sim_7.get_winning_rate(), sim_a.get_winning_rate(), sim_b.get_winning_rate())
# Out:
# 0.5585106382978723 0.582089552238806 0.5520833333333334 0.5256410256410257 0.6141732283464567

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.251818333909252 0.254644483386662 0.2491096289593807 0.343085924957246 0.18929693298922878
