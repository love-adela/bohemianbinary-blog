# %%
import db

# %%
import coin_repository

# %%
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
import strategies as st

# %%
import simulator

# %%
sim = simulator.Simulator(st.GcdcStrategy(coin_repository.CoinRepository('MIOTA')))

# %%
sim.get_data_frame()['close'].plot()

# %%
sim.get_data_frame()['benefit'].plot()

# %%
sim.get_mdd()
# Out:
# 0.8376049468202633

# %%
sim.get_cagr()
# Out:
# -0.10456353794856432

# %%
# data.get_data_frame()['benefit'].plot()

# %%
eth_repo = coin_repository.CoinRepository('MIOTA')
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=0.7))
sim_a = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=-1))
sim_b = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=-1, k_factor=20))
sim_c = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, k_value=-1, k_factor=10))

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.5872644669149808 0.5844988145827652 0.3219304863425697 0.3759972992904995 0.48597851636786615

# %%
pd.DataFrame({
#     '0.3': sim_3.get_data_frame()['benefit'],
    '0.5': sim_5.get_data_frame()['benefit'],
#     '0.7': sim_7.get_data_frame()['benefit'],
    '-1' : sim_a.get_data_frame()['benefit'],
    '-1 / 20' : sim_b.get_data_frame()['benefit'],
    '-1 / 10' : sim_c.get_data_frame()['benefit']
}).plot()

# %%
print(sim_3.get_cagr(), sim_5.get_cagr(), sim_7.get_cagr(), sim_a.get_cagr(), sim_b.get_cagr())
# Out:
# 20.226859251677563 6.326710415171657 3.8412365405313293 14.741388972853409 8.929298755805409

# %%
print(sim_3.get_winning_rate(), sim_5.get_winning_rate(), sim_7.get_winning_rate(), sim_a.get_winning_rate(), sim_b.get_winning_rate())
# Out:
# 0.583756345177665 0.5833333333333334 0.5764705882352941 0.6 0.609375

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.5872644669149808 0.5844988145827652 0.3219304863425697 0.3759972992904995 0.48597851636786615
