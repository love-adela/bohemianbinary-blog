# %%
import db

# %%
import coin_repository

# %%
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
import strategies as st

# %%
import simulator

# %%
sim = simulator.Simulator(st.GcdcStrategy(coin_repository.CoinRepository('XRP')))

# %%
sim.get_data_frame()['benefit'].plot()

# %%
sim.get_mdd()
# Out:
# 0.8528704100381743

# %%
sim.get_cagr()
# Out:
# 0.6822225120071894

# %%
# data.get_data_frame()['benefit'].plot()

# %%
xrp_repo = coin_repository.CoinRepository('XRP')
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=0.7))
sim_a = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=-1))
sim_b = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=-1, k_factor=20))
sim_c = simulator.Simulator(st.VolatilityBreakoutStrategy(xrp_repo, k_value=-1, k_factor=10))

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.3096662547293818 0.17731346034232542 0.22330097087378642 0.13334885326566615 0.19920445262464948

# %%
pd.DataFrame({
#     '0.3': sim_3.get_data_frame()['benefit'],
    '0.5': sim_5.get_data_frame()['benefit'],
#     '0.7': sim_7.get_data_frame()['benefit'],
    '-1' : sim_a.get_data_frame()['benefit'],
    '-1 / 20' : sim_b.get_data_frame()['benefit'],
    '-1 / 10' : sim_c.get_data_frame()['benefit']
}).plot()

# %%
print(sim_3.get_cagr(), sim_5.get_cagr(), sim_7.get_cagr(), sim_a.get_cagr(), sim_b.get_cagr())
# Out:
# 26.572389871862875 22.763388240426032 13.55259158167873 55.990376358812824 24.707572387708566

# %%
print(sim_3.get_winning_rate(), sim_5.get_winning_rate(), sim_7.get_winning_rate(), sim_a.get_winning_rate(), sim_b.get_winning_rate())
# Out:
# 0.5966850828729282 0.64 0.6195652173913043 0.6544117647058824 0.6451612903225806

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.3096662547293818 0.17731346034232542 0.22330097087378642 0.13334885326566615 0.19920445262464948
