# %%
import db

# %%
import coin_repository

# %%
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
import strategies as st

# %%
import simulator

# %%
sim = simulator.Simulator(st.GcdcStrategy(coin_repository.CoinRepository('XRP')))

# %%
sim.get_data_frame()['benefit'].plot()

# %%
sim.get_mdd()
# Out:
# 0.8528704100381742

# %%
sim.get_cagr()
# Out:
# 0.6781394388572397

# %%
# data.get_data_frame()['benefit'].plot()

# %%
eth_repo = coin_repository.CoinRepository('XRP')
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, 0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, 0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, 0.7))
sim_a = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, -1))
sim_b = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, -1, 20))
sim_c = simulator.Simulator(st.VolatilityBreakoutStrategy(eth_repo, -1, 10))

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd(), sim_a.get_mdd(), sim_b.get_mdd())
# Out:
# 0.3096662547293818 0.1773134603423253 0.22330097087378642 0.1333488532656658 0.1992044526246497

# %%
pd.DataFrame({
#     '0.3': sim_3.get_data_frame()['benefit'],
    '0.5': sim_5.get_data_frame()['benefit'],
#     '0.7': sim_7.get_data_frame()['benefit'],
    '-1' : sim_a.get_data_frame()['benefit'],
    '-1 / 20' : sim_b.get_data_frame()['benefit'],
    '-1 / 10' : sim_c.get_data_frame()['benefit']
}).plot()

# %%
print(sim_3.get_cagr(), sim_5.get_cagr(), sim_7.get_cagr(), sim_a.get_cagr(), sim_b.get_cagr())
# Out:
# 35.18918093898746 25.772697915376927 14.36507654017598 57.80934675033779 29.36114769595239

# %%
print(sim_3.get_winning_rate(), sim_5.get_winning_rate(), sim_7.get_winning_rate(), sim_a.get_winning_rate(), sim_b.get_winning_rate())
# Out:
# 0.6055555555555555 0.6349206349206349 0.6413043478260869 0.6642335766423357 0.64
