# %%
import db

# %%
#db.create_db()

# %%
import ripple_repository

# %%
# ripple_repository.print_stock()

# %%
# ripple_repository.populate()

# %%
# ripple_repository.get_data()

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(ripple_repository.get_data())
df.plot()

# %%
origin = ripple_repository.get_data()
data = {
    'high': origin['high'],
    'low' : origin['low']
}
middle = {}

for x in data['high']:
    middle[x] = (data['high'][x] + data['low'][x]) / 2
data['middle'] = middle

df = pd.DataFrame(data)
df.plot()
