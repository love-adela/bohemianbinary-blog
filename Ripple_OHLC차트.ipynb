# %%
import db

# %%
#db.create_db()

# %%
import coin_repository

# %%
# coin_repository.CoinRepository('XRP')print_stock()

# %%
# coin_repository.CoinRepository('XRP').populate()

# %%
# coin_repository.CoinRepository('XRP').get_data()

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(coin_repository.CoinRepository('XRP').get_data())
df.plot()

# %%
origin = coin_repository.CoinRepository('XRP').get_data()
data = {
    'high': origin['high'],
    'low' : origin['low']
}
middle = {}

for x in data['high']:
    middle[x] = (data['high'][x] + data['low'][x]) / 2
data['middle'] = middle

df = pd.DataFrame(data)
df.plot()
