# %%
import coin_repo

# %%
repo = coin_repo.CoinRepo('ETH')

# %%
repo.print_stock()
# Out:
# low: 238.65 / high: 311.46 / open: 302.95 / close: 272.69 / date: 2017-06-26
# low: 227.14 / high: 293.09 / open: 272.69 / close: 293.09 / date: 2017-06-27
# low: 276.41 / high: 333.1 / open: 293.04 / close: 327.93 / date: 2017-06-28
# low: 297.37 / high: 330.71 / open: 328.37 / close: 302.88 / date: 2017-06-29
# low: 288.44 / high: 315.17 / open: 303.15 / close: 294.92 / date: 2017-06-30
# low: 268.62 / high: 293.75 / open: 293.35 / close: 274.6 / date: 2017-07-01
# low: 262.52 / high: 295.51 / open: 275.12 / close: 287.99 / date: 2017-07-02
# low: 281.18 / high: 291.1 / open: 288.41 / close: 282.9 / date: 2017-07-03
# low: 273.11 / high: 287.39 / open: 282.19 / close: 273.3 / date: 2017-07-04
# low: 261.45 / high: 275.13 / open: 273.1 / close: 268.77 / date: 2017-07-05
# low: 265.51 / high: 278.48 / open: 268.86 / close: 270.55 / date: 2017-07-06
# low: 244.17 / high: 273.94 / open: 270.35 / close: 245.99 / date: 2017-07-07
# ...

# %%
repo.populate()

# %%
repo.get_data()
# Out:
# {'open': {datetime.date(2017, 6, 26): 0.29877,
#   datetime.date(2017, 6, 27): 0.277288,
#   datetime.date(2017, 6, 28): 0.275391,
#   datetime.date(2017, 6, 29): 0.280565,
#   datetime.date(2017, 6, 30): 0.26606,
#   datetime.date(2017, 7, 1): 0.262855,
#   datetime.date(2017, 7, 2): 0.254512,
#   datetime.date(2017, 7, 3): 0.258977,
#   datetime.date(2017, 7, 4): 0.259841,
#   datetime.date(2017, 7, 5): 0.255125,
#   datetime.date(2017, 7, 6): 0.256374,
#   datetime.date(2017, 7, 7): 0.254858,
#   datetime.date(2017, 7, 8): 0.239741,
#   datetime.date(2017, 7, 9): 0.236884,
#   datetime.date(2017, 7, 10): 0.234067,
#   datetime.date(2017, 7, 11): 0.196415,
#   datetime.date(2017, 7, 12): 0.184198,
#   datetime.date(2017, 7, 13): 0.205873,
#   datetime.date(2017, 7, 14): 0.200819,
#   datetime.date(2017, 7, 15): 0.190976,
#   datetime.date(2017, 7, 16): 0.16948,
#   datetime.date(2017, 7, 17): 0.150146,
#   datetime.date(2017, 7, 18): 0.179668,
# ...

# %%
repo.get_data_as_lists()
# Out:
# ([datetime.date(2017, 6, 26),
#   datetime.date(2017, 6, 26),
#   datetime.date(2017, 6, 27),
#   datetime.date(2017, 6, 27),
#   datetime.date(2017, 6, 28),
#   datetime.date(2017, 6, 28),
#   datetime.date(2017, 6, 29),
#   datetime.date(2017, 6, 29),
#   datetime.date(2017, 6, 30),
#   datetime.date(2017, 6, 30),
#   datetime.date(2017, 7, 1),
#   datetime.date(2017, 7, 1),
#   datetime.date(2017, 7, 2),
#   datetime.date(2017, 7, 2),
#   datetime.date(2017, 7, 3),
#   datetime.date(2017, 7, 3),
#   datetime.date(2017, 7, 4),
#   datetime.date(2017, 7, 4),
#   datetime.date(2017, 7, 5),
#   datetime.date(2017, 7, 5),
#   datetime.date(2017, 7, 6),
#   datetime.date(2017, 7, 6),
#   datetime.date(2017, 7, 7),
#   datetime.date(2017, 7, 7),
#   datetime.date(2017, 7, 8),
#   datetime.date(2017, 7, 8),
#   datetime.date(2017, 7, 9),
#   datetime.date(2017, 7, 9),
#   datetime.date(2017, 7, 10),
#   datetime.date(2017, 7, 10),
#   datetime.date(2017, 7, 11),
# ...
