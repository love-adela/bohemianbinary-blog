# %%
import db

# %%
#db.create_db()

# %%
import bitcoin_repository

# %%
# bitcoin_repository.print_stock()

# %%
# bitcoin_repository.populate()

# %%
# bitcoin_repository.get_data()

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(bitcoin_repository.get_data())
df.plot()

# %%
origin = bitcoin_repository.get_data()
data = {
    'high': origin['high'],
    'low' : origin['low']
}
middle = {}

for x in data['high']:
    middle[x] = (data['high'][x] + data['low'][x]) / 2
data['middle'] = middle

df = pd.DataFrame(data)
df.plot()
