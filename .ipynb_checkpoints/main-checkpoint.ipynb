# %%
import db

# %%
import coin_repository

# %%
from matplotlib import pyplot as plt
import pandas as pd
import math

# %%
import strategies as st

# %%
import simulator

# %%
sim = simulator.Simulator(st.GcdcStrategy(coin_repository.CoinRepository('ETH')))

# %%
sim.get_data_frame()['benefit'].plot()

# %%
sim.get_mdd()
# Out:
# 0.6764474517090633

# %%
sim.get_cagr()
# Out:
# 1.2649496354605914

# %%
# data.get_data_frame()['benefit'].plot()

# %%
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.7))

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd())
# Out:
# 0.3350003357783209 0.14373871985243425 0.17086474649155847

# %%
pd.DataFrame({
    '0.3': sim_3.get_data_frame()['benefit'],
    '0.5': sim_5.get_data_frame()['benefit'],
    '0.7': sim_7.get_data_frame()['benefit']
}).plot()

# %%
print(sim_3.get_mdd(), sim_5.get_mdd(), sim_7.get_mdd())
# Out:
# 0.3350003357783209 0.14373871985243425 0.17086474649155847

# %%
print(sim_3.get_cagr(), sim_5.get_cagr(), sim_7.get_cagr())
# Out:
# 10.353246873198449 5.902962186297336 3.3025031352278296

# %%
sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.3))
sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.5))
sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4e353f701800> in <module>()
# ----> 1 sim_3 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.3))
#       2 sim_5 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.5))
#       3 sim_7 = simulator.Simulator(st.VolatilityBreakoutStrategy(coin_repository.CoinRepository('ETH'), 0.7))
#
# ~/repo/anl/simulator.py in __init__(self, strategy)
#      10         max_benefit = -1
#      11
# ---> 12         index = self.data_frame['close'].keys()
#      13
#      14         for date in index:
#
# TypeError: 'CoinRepository' object is not subscriptable

# %%
pd.DataFrame({
    '0.3': sim_3['benefit'],
    '0.5': sim_5['benefit'],
    '0.7': sim_7['benefit']
}).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-a2c8c15a7621> in <module>()
#       1 pd.DataFrame({
# ----> 2     '0.3': sim_3['benefit'],
#       3     '0.5': sim_5['benefit'],
#       4     '0.7': sim_7['benefit']
#       5 }).plot()
#
# TypeError: 'Simulator' object is not subscriptable

# %%
# class MddCagr:
#     def __init__(self, coin_type):
#         self.coin_type = coin_type
#         self.coin_full_name = {
#             'ETH': 'ethereum',
#             'BTC': 'bitcoin',
#             'XRP': 'ripple'
#         }[coin_type]
    
#     def check_mddcagr(self):
#         (index, origin) = coin_repository.CoinRepository(f'{self.coin_full_name}').get_data_as_lists()
#         data = {}
#         new_index = index
#         close_series = pd.Series(origin['close'], new_index)
#         data['ma5'] = close_series.rolling(window=5).mean()
#         data['ma20'] = close_series.rolling(window=20).mean()
#         # df = pd.DataFrame(data, new_index)
#         # df.plot()
#         previous_ma5 = -1
#         previous_ma20 = -1
#         previous_close = -1
#         benefits = []
#         drawdowns = []
#         bought = False
#         max_close = -1

#         for tuple in zip(data['ma5'], data['ma20'], origin['close'], index):
#             if tuple[0] > tuple[1] and previous_ma5 <= previous_ma20:
#                 print(f"golden cross: {tuple}")
#                 bought = True
#                 if len(benefits) == 0:
#                     benefits.append(1)
#                 else:
#                     benefits.append(benefits[-1])
#             elif tuple[0] < tuple[1] and previous_ma5 >= previous_ma20:
#                 print(f"dead cross: {tuple}")
#                 bought = False
#                 benefits.append(benefits[-1] * (tuple[2] / previous_close))
#             else:
#                 if len(benefits) == 0:
#                     benefits.append(1)
#                 elif bought:
#                     benefits.append(benefits[-1] * (tuple[2] / previous_close))
#                 else:
#                     benefits.append(benefits[-1])

#         if (tuple[2] > max_close):
#             max_close = tuple[2]

#         drawdowns.append(1 - (tuple[2] / max_close))

#         previous_ma5 = tuple[0]
#         previous_ma20 = tuple[1]
#         previous_close = tuple[2]

#         df = pd.Series(benefits, index)
#         df.plot()

#         # df = pd.Series(drawdowns, index)
#         # df.plot()

#         print(f"{coin_full_name}MDD: {max(drawdowns) * 100}%")
#         print(f"CAGR: {(benefits[-1] - 1) * 100}%")
