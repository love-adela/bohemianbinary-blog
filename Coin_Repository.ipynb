# %%
import coin_repository

# %%
ETH_repo = coin_repository.CoinRepository('ETH')

# %%
#coin_repository.CoinRepository.create_db()

# %%
ETH_repo.update_stock()

# %%
ETH_repo.print_stock()

# %%
ETH_repo.get_data()
# Out:
# {'open': {datetime.date(2017, 6, 26): 302.95,
#   datetime.date(2017, 6, 27): 272.69,
#   datetime.date(2017, 6, 28): 293.04,
#   datetime.date(2017, 6, 29): 328.37,
#   datetime.date(2017, 6, 30): 303.15,
#   datetime.date(2017, 7, 1): 293.35,
#   datetime.date(2017, 7, 2): 275.12,
#   datetime.date(2017, 7, 3): 288.41,
#   datetime.date(2017, 7, 4): 282.19,
#   datetime.date(2017, 7, 5): 273.1,
#   datetime.date(2017, 7, 6): 268.86,
#   datetime.date(2017, 7, 7): 270.35,
#   datetime.date(2017, 7, 8): 245.89,
#   datetime.date(2017, 7, 9): 251.82,
#   datetime.date(2017, 7, 10): 243.01,
#   datetime.date(2017, 7, 11): 211.53,
#   datetime.date(2017, 7, 12): 197.15,
#   datetime.date(2017, 7, 13): 231.81,
#   datetime.date(2017, 7, 14): 209.53,
#   datetime.date(2017, 7, 15): 199.71,
#   datetime.date(2017, 7, 16): 169.57,
#   datetime.date(2017, 7, 17): 159.99,
#   datetime.date(2017, 7, 18): 195.03,
#   datetime.date(2017, 7, 19): 234.94,
#   datetime.date(2017, 7, 20): 205.42,
# ...

# %%
ETH_repo.get_data_as_lists()
# Out:
# ([datetime.date(2017, 6, 26),
#   datetime.date(2017, 6, 27),
#   datetime.date(2017, 6, 28),
#   datetime.date(2017, 6, 29),
#   datetime.date(2017, 6, 30),
#   datetime.date(2017, 7, 1),
#   datetime.date(2017, 7, 2),
#   datetime.date(2017, 7, 3),
#   datetime.date(2017, 7, 4),
#   datetime.date(2017, 7, 5),
#   datetime.date(2017, 7, 6),
#   datetime.date(2017, 7, 7),
#   datetime.date(2017, 7, 8),
#   datetime.date(2017, 7, 9),
#   datetime.date(2017, 7, 10),
#   datetime.date(2017, 7, 11),
#   datetime.date(2017, 7, 12),
#   datetime.date(2017, 7, 13),
#   datetime.date(2017, 7, 14),
#   datetime.date(2017, 7, 15),
#   datetime.date(2017, 7, 16),
#   datetime.date(2017, 7, 17),
#   datetime.date(2017, 7, 18),
#   datetime.date(2017, 7, 19),
#   datetime.date(2017, 7, 20),
#   datetime.date(2017, 7, 21),
#   datetime.date(2017, 7, 22),
#   datetime.date(2017, 7, 23),
#   datetime.date(2017, 7, 24),
#   datetime.date(2017, 7, 25),
#   datetime.date(2017, 7, 26),
# ...

# %%
# import datetime
# end_date = datetime.datetime.now()
# duration = 365
# start_date = end_date - datetime.timedelta(duration)
# print(start_date, end_date)
# end_date.strftime("%Y%m%d")

# %%
BTC_repo = coin_repository.CoinRepository('BTC')

# %%
BTC_repo.update_stock()

# %%
BTC_repo.print_stock()

# %%
BTC_repo.get_data()
# Out:
# {'open': {datetime.date(2017, 7, 15): 2230.12,
#   datetime.date(2017, 7, 16): 1991.98,
#   datetime.date(2017, 7, 17): 1932.62,
#   datetime.date(2017, 7, 18): 2233.52,
#   datetime.date(2017, 7, 19): 2323.08,
#   datetime.date(2017, 7, 20): 2269.89,
#   datetime.date(2017, 7, 21): 2838.41,
#   datetime.date(2017, 7, 22): 2668.63,
#   datetime.date(2017, 7, 23): 2808.1,
#   datetime.date(2017, 7, 24): 2732.7,
#   datetime.date(2017, 7, 25): 2757.5,
#   datetime.date(2017, 7, 26): 2577.77,
#   datetime.date(2017, 7, 27): 2538.71,
#   datetime.date(2017, 7, 28): 2679.73,
#   datetime.date(2017, 7, 29): 2807.02,
#   datetime.date(2017, 7, 30): 2724.39,
#   datetime.date(2017, 7, 31): 2763.24,
#   datetime.date(2017, 8, 1): 2871.3,
#   datetime.date(2017, 8, 2): 2727.13,
#   datetime.date(2017, 8, 3): 2709.56,
#   datetime.date(2017, 8, 4): 2806.93,
#   datetime.date(2017, 8, 5): 2897.63,
#   datetime.date(2017, 8, 6): 3257.61,
#   datetime.date(2017, 8, 7): 3212.78,
# ...

# %%
BTC_repo.get_data_as_lists()
# Out:
# ([datetime.date(2017, 7, 15),
#   datetime.date(2017, 7, 16),
#   datetime.date(2017, 7, 17),
#   datetime.date(2017, 7, 18),
#   datetime.date(2017, 7, 19),
#   datetime.date(2017, 7, 20),
#   datetime.date(2017, 7, 21),
#   datetime.date(2017, 7, 22),
#   datetime.date(2017, 7, 23),
#   datetime.date(2017, 7, 24),
#   datetime.date(2017, 7, 25),
#   datetime.date(2017, 7, 26),
#   datetime.date(2017, 7, 27),
#   datetime.date(2017, 7, 28),
#   datetime.date(2017, 7, 29),
#   datetime.date(2017, 7, 30),
#   datetime.date(2017, 7, 31),
#   datetime.date(2017, 8, 1),
#   datetime.date(2017, 8, 2),
#   datetime.date(2017, 8, 3),
#   datetime.date(2017, 8, 4),
#   datetime.date(2017, 8, 5),
#   datetime.date(2017, 8, 6),
#   datetime.date(2017, 8, 7),
#   datetime.date(2017, 8, 8),
#   datetime.date(2017, 8, 9),
#   datetime.date(2017, 8, 10),
#   datetime.date(2017, 8, 11),
#   datetime.date(2017, 8, 12),
#   datetime.date(2017, 8, 13),
#   datetime.date(2017, 8, 14),
# ...

# %%
XRP_repo = coin_repository.CoinRepository('XRP')

# %%
XRP_repo.update_stock()

# %%
XRP_repo.print_stock()

# %%
XRP_repo.get_data()
# Out:
# {'open': {datetime.date(2017, 7, 15): 0.190976,
#   datetime.date(2017, 7, 16): 0.16948,
#   datetime.date(2017, 7, 17): 0.150146,
#   datetime.date(2017, 7, 18): 0.179668,
#   datetime.date(2017, 7, 19): 0.188498,
#   datetime.date(2017, 7, 20): 0.170017,
#   datetime.date(2017, 7, 21): 0.18943,
#   datetime.date(2017, 7, 22): 0.182168,
#   datetime.date(2017, 7, 23): 0.193568,
#   datetime.date(2017, 7, 24): 0.194979,
#   datetime.date(2017, 7, 25): 0.19228,
#   datetime.date(2017, 7, 26): 0.177582,
#   datetime.date(2017, 7, 27): 0.17521,
#   datetime.date(2017, 7, 28): 0.173211,
#   datetime.date(2017, 7, 29): 0.165218,
#   datetime.date(2017, 7, 30): 0.169494,
#   datetime.date(2017, 7, 31): 0.16505,
#   datetime.date(2017, 8, 1): 0.168024,
#   datetime.date(2017, 8, 2): 0.177531,
#   datetime.date(2017, 8, 3): 0.173218,
#   datetime.date(2017, 8, 4): 0.174555,
#   datetime.date(2017, 8, 5): 0.173865,
#   datetime.date(2017, 8, 6): 0.185398,
# ...

# %%
XRP_repo.get_data_as_lists()
# Out:
# ([datetime.date(2017, 7, 15),
#   datetime.date(2017, 7, 16),
#   datetime.date(2017, 7, 17),
#   datetime.date(2017, 7, 18),
#   datetime.date(2017, 7, 19),
#   datetime.date(2017, 7, 20),
#   datetime.date(2017, 7, 21),
#   datetime.date(2017, 7, 22),
#   datetime.date(2017, 7, 23),
#   datetime.date(2017, 7, 24),
#   datetime.date(2017, 7, 25),
#   datetime.date(2017, 7, 26),
#   datetime.date(2017, 7, 27),
#   datetime.date(2017, 7, 28),
#   datetime.date(2017, 7, 29),
#   datetime.date(2017, 7, 30),
#   datetime.date(2017, 7, 31),
#   datetime.date(2017, 8, 1),
#   datetime.date(2017, 8, 2),
#   datetime.date(2017, 8, 3),
#   datetime.date(2017, 8, 4),
#   datetime.date(2017, 8, 5),
#   datetime.date(2017, 8, 6),
#   datetime.date(2017, 8, 7),
#   datetime.date(2017, 8, 8),
#   datetime.date(2017, 8, 9),
#   datetime.date(2017, 8, 10),
#   datetime.date(2017, 8, 11),
#   datetime.date(2017, 8, 12),
#   datetime.date(2017, 8, 13),
#   datetime.date(2017, 8, 14),
# ...
